# %% [markdown]
# # Data Science Tools and Ecosytem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * Create lists
# * Create tables
# * Create arithmeticexpressions

# %% [markdown]
# ## Author:
# Oliver Pack

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java
# etc.

# %%
Some of the commonly used libraries used by Data Scientists include:
- Panda
- NumPy
- SciPy
- Matplotlib
etc.

# %% [markdown]
# | Data Sience Tools |
# | ------ |
# | Watson Studio|
# | Microsoft Azure|
# | Weka|
# | Apache Hadoop|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers 
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
min_value=  200
hour_value = min_value // 60
min_value_rest = min_value - (hour_value*60)
print ("Converted min value in hour:",hour_value)
print ("Converted min value rest in minutes:",min_value_rest)
# Out:
# Converted min value in hour: 3
# Converted min value rest in minutes: 20
